# %%
import matplotlib
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
import numpy as np
import input_data

# %%
mnist_width = 28
n_visible = mnist_width * mnist_width
n_hidden = 10
nBatch = 128

# %%
# create node for input data
X = tf.placeholder("float", [nBatch, n_visible], name='X')
H = tf.placeholder("float", [nBatch, n_hidden], name='H')

# %%
# create nodes for hidden variables
C_max = 4 * np.sqrt(6. / (n_visible + n_hidden))
C_init = tf.random_uniform(shape=[n_visible, n_hidden],
                           minval=-C_max,
                           maxval=C_max)

C = tf.Variable(C_init, name='C')

# %%
print C.get_shape()
print X.get_shape()
print H.get_shape()
# Out:
# (784, 10)
# (128, 784)
# (128, 10)

# %%
C2 = tf.expand_dims(tf.transpose(C),0)
X2 = tf.expand_dims(X,1)
print C2.get_shape()
print X2.get_shape()
# Out:
# (1, 10, 784)
# (128, 1, 784)

# %%
dist = tf.reduce_sum(tf.square(tf.sub(X2,C2)),2)
cost = tf.reduce_sum(tf.reduce_min(dist,1))
#print assign.get_shape()

# %%
train_op = tf.train.GradientDescentOptimizer(0.01).minimize(cost)  # construct an optimizer
#train_op = tf.train.AdamOptimizer().minimize(cost)
mnist = input_data.read_data_sets("/mnt/hdd1/thkim/dataset/MNIST", one_hot=True)
trX, trY, teX, teY = mnist.train.images, mnist.train.labels, mnist.test.images, mnist.test.labels
# Out:
# ('Extracting', '/mnt/hdd1/thkim/dataset/MNIST/train-images-idx3-ubyte.gz')
# ('Extracting', '/mnt/hdd1/thkim/dataset/MNIST/train-labels-idx1-ubyte.gz')
# ('Extracting', '/mnt/hdd1/thkim/dataset/MNIST/t10k-images-idx3-ubyte.gz')
# ('Extracting', '/mnt/hdd1/thkim/dataset/MNIST/t10k-labels-idx1-ubyte.gz')
# /usr/lib/python2.7/gzip.py:268: VisibleDeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   chunk = self.extrabuf[offset: offset + size]
# input_data.py:42: VisibleDeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   data = data.reshape(num_images, rows, cols, 1)

# %%
# Launch the graph in a session
sess = tf.Session()

# you need to initialize all variables
tf.initialize_all_variables().run(session=sess)
print('-1', sess.run(cost, feed_dict={X: teX[:128]}))
for i in range(100):
    for start, end in zip(range(0, len(trX), 128), range(128, len(trX), 128)):
        input_ = trX[start:end]
        sess.run(train_op, feed_dict={X: input_})
    print(i, sess.run(cost, feed_dict={X: teX[:128]}))
# Out:
# ('-1', 13639.956)
# (0, 6329.1924)
# (1, 5833.8838)
# (2, 5818.9585)
# (3, 5771.1113)
# (4, 5771.1113)
# (5, 5771.1113)
# (6, 5771.1113)
# (7, 5771.1113)
# (8, 5771.1113)
# (9, 5771.1113)
# (10, 5771.1113)
# (11, 5771.1113)
# (12, 5771.1113)
# (13, 5771.1113)
# (14, 5771.1113)
# (15, 5771.1113)
# (16, 5771.1113)
# (17, 5771.1113)
# (18, 5771.1113)
# (19, 5771.1113)
# (20, 5771.1113)
# (21, 5771.1113)
# (22, 5771.1113)
# (23, 5771.1113)
# (24, 5771.1113)
# (25, 5771.1113)
# (26, 5771.1113)
# (27, 5771.1113)
# (28, 5771.1113)
# (29, 5771.1113)
# (30, 5771.1113)
# (31, 5771.1113)
# (32, 5771.1113)
# (33, 5771.1113)
# (34, 5771.1113)
# (35, 5771.1113)
# (36, 5771.1113)
# (37, 5771.1113)
# (38, 5771.1113)
# (39, 5771.1113)
# (40, 5771.1113)
# (41, 5771.1113)
# (42, 5771.1113)
# (43, 5771.1113)
# (44, 5771.1113)
# (45, 5771.1113)
# (46, 5771.1113)
# (47, 5771.1113)
# (48, 5771.1113)
# (49, 5771.1113)
# (50, 5771.1113)
# (51, 5771.1113)
# (52, 5771.1113)
# (53, 5771.1113)
# (54, 5771.1113)
# ...

# %%
cent=sess.run(C)

# %%
cent.shape

# %%
cent = np.reshape(cent,(28,28,10))
plt.imshow(cent[:,:,6])
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
# Experimtents on slicing
import numpy as np
import tensorflow as tf

A = tf.placeholder('float',[4,5])
B = tf.argmin(A,1)
C = tf.to_int64(tf.range(0,B.get_shape()[0]))
D = tf.concat(1,[tf.expand_dims(C,1),tf.expand_dims(B,1)])
E = tf.gather_nd(A,D)
F = tf.reduce_sum(E)

with tf.Session() as sess:
    tf.initialize_all_variables().run()
    #A_in = np.random.random((4,5))
    print A_in
    out = sess.run([B,C,D,E,F], feed_dict={A:A_in})
    for ii in out:
        print ii

# %%
A = tf.placeholder('float',[4,5])
B = tf.reduce_min(A,1)

with tf.Session() as sess:
    tf.initialize_all_variables().run()
    A_in = np.random.random((4,5))
    print A_in
    out = sess.run([B], feed_dict={A:A_in})
    for ii in out:
        print ii

# %% [markdown]
# cost = tf.concat(0, [
#     tf.reduce_sum(
#       tf.gather(dist,
#                 tf.reshape(
#                   tf.where(
#                     tf.equal(assign, c)
#                   ),[1,-1])
#                ),reduction_indices=[1])
#   for c in xrange(n_hidden)])
#
# B = tf.to_int32(tf.argmin(dist,1))
# C = tf.range(0,B.get_shape()[0])
# D = tf.concat(1,[tf.expand_dims(C,1),tf.expand_dims(B,1)])
# E = tf.gather_nd(dist,D)
# cost = tf.reduce_sum(E)
